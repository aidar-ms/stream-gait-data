# %% [markdown]
# Approach
# - Pick 5 users and get 100 records per each walking surface
# - Enumerate records
# - Each enumerated id is a partition and surfaces are classes

# %%
import pandas as pd

from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from tsfresh import extract_features, select_features
from tsfresh.utilities.dataframe_functions import impute

# %%
data = pd.read_csv("sampled_data/data.csv")
data.describe()
# Out:
#              UserId  PacketCounter  SampleTimeFine         Acc_X  \
# count  1.708236e+06   1.708236e+06             0.0  1.693804e+06
# mean   1.550002e+01   3.225632e+04             NaN  9.838823e+00
# std    8.654662e+00   1.917977e+04             NaN  1.490878e+02
# min    1.000000e+00   0.000000e+00             NaN -1.376947e+05
# 25%    8.000000e+00   1.507900e+04             NaN  7.076802e+00
# 50%    1.600000e+01   3.216300e+04             NaN  9.597096e+00
# 75%    2.300000e+01   4.921100e+04             NaN  1.306224e+01
# max    3.000000e+01   6.553500e+04             NaN  1.194948e+02
#
#               Acc_Y         Acc_Z     FreeAcc_X     FreeAcc_Y     FreeAcc_Z  \
# count  1.693804e+06  1.693804e+06  1.693804e+06  1.693804e+06  1.693804e+06
# mean   9.067474e-01 -7.830717e-02 -1.514832e-01  1.432863e-01 -1.293384e-01
# std    2.010112e+02  8.939607e+01  1.354799e+02  1.363478e+02  1.126015e+02
# min   -1.854641e+05 -9.034852e+01 -1.246128e+05 -7.910270e+01 -1.034285e+05
# 25%   -8.746855e-01 -2.809921e+00 -2.008377e+00 -2.668110e+00 -2.727015e+00
# 50%    8.244235e-01 -7.924415e-01 -4.086850e-02  2.297000e-03 -7.947700e-02
# 75%    2.870030e+00  1.985747e+00  1.995095e+00  2.776245e+00  2.630229e+00
# max    9.340336e+01  8.577615e+04  6.455670e+01  1.253817e+05  1.569266e+02
#
#               Gyr_X  ...     OriInc_q3          Roll         Pitch  \
# count  1.693804e+06  ...  1.693804e+06  1.693804e+06  1.693804e+06
# mean   4.703301e-02  ... -6.346451e-04  3.895021e+01 -7.090170e+01
# std    2.040233e+00  ...  3.301078e-03  9.922891e+01  9.823791e+00
# min   -1.959829e+02  ... -7.032000e-02 -1.800000e+02 -8.999649e+01
# 25%   -1.031616e+00  ... -2.157000e-03 -3.304743e+00 -7.826868e+01
# 50%    4.664750e-02  ... -2.370000e-04  2.974054e+01 -7.164629e+01
# 75%    1.115163e+00  ...  1.069000e-03  1.306391e+02 -6.512706e+01
# max    2.000270e+02  ...  5.071500e-02  1.799999e+02  7.346872e+01
#
#                 Yaw  Latitude  Longitude   Altitude  Vel_X  Vel_Y  Vel_Z
# count  1.693804e+06       0.0        0.0  1708236.0    0.0    0.0    0.0
# mean  -6.138306e-01       NaN        NaN        0.0    NaN    NaN    NaN
# std    1.003020e+02       NaN        NaN        0.0    NaN    NaN    NaN
# min   -1.799997e+02       NaN        NaN        0.0    NaN    NaN    NaN
# 25%   -7.961625e+01       NaN        NaN        0.0    NaN    NaN    NaN
# 50%   -3.291615e+01       NaN        NaN        0.0    NaN    NaN    NaN
# 75%    8.225846e+01       NaN        NaN        0.0    NaN    NaN    NaN
# max    1.799999e+02       NaN        NaN        0.0    NaN    NaN    NaN
#
# [8 rows x 31 columns]

# %%
# Drop unneeded and NaN columns
data.dropna(axis=1, how="all", inplace=True)
data.drop(["PacketCounter", "Altitude", "SensorLoc"], axis=1, inplace=True)
data.head(5)
# Out:
#    UserId Surface     Acc_X     Acc_Y     Acc_Z  FreeAcc_X  FreeAcc_Y  \
# 0       1   CALIB  9.492260  0.130429 -2.558672  -0.000000  -0.000000
# 1       1   CALIB  9.521406  0.118498 -2.408461  -0.046313   0.186881
# 2       1   CALIB  9.544091  0.187095 -2.204060  -0.019889   0.402747
# 3       1   CALIB  9.573117  0.162900 -2.168100  -0.052578   0.442471
# 4       1   CALIB  9.653494  0.251947 -2.118363   0.018708   0.531586
#
#    FreeAcc_Z     Gyr_X     Gyr_Y  ...  VelInc_X  VelInc_Y  VelInc_Z  \
# 0   0.019241 -0.025877 -0.028406  ...  0.094926  0.001303 -0.025573
# 1   0.007437 -0.002117 -0.030708  ...  0.095218  0.001189 -0.024070
# 2  -0.023921 -0.001215 -0.028015  ...  0.095444  0.001874 -0.022027
# 3  -0.005893 -0.000991 -0.038044  ...  0.095735  0.001630 -0.021663
# 4   0.059392 -0.007314 -0.033840  ...  0.096539  0.002515 -0.021167
#
#    OriInc_q0  OriInc_q1  OriInc_q2  OriInc_q3        Roll      Pitch  \
# 0        1.0  -0.000129  -0.000142   0.000024  177.082561 -74.903636
# 1        1.0  -0.000011  -0.000154   0.000043  177.231488 -74.656365
# 2        1.0  -0.000006  -0.000140   0.000036  177.248779 -74.640533
# 3        1.0  -0.000005  -0.000190   0.000009  177.257435 -74.619164
# 4        1.0  -0.000037  -0.000169  -0.000034  177.242447 -74.599610
#
#           Yaw
# 0  103.717809
# 1  104.388684
# 2  104.370032
# 3  104.360623
# 4  104.371823
#
# [5 rows x 24 columns]

# %%
data.dropna(how="any", inplace=True)

# %%
from sklearn import preprocessing

# Encode data
le = preprocessing.LabelEncoder()
data["Surface"] = le.fit_transform(data["Surface"])

# %%
# Pick 5 users
data_5 = data[data["UserId"] <= 5]

for user_id in data_5.UserId.unique():
    print(f"Surfaces of user {user_id}:", " ".join(map(str, data_5[data_5.UserId == user_id].Surface.unique())))
# Out:
# Surfaces of user 1: 2 6 4 7 0 1 5 9 3 8
# Surfaces of user 2: 2 6 4 7 0 1 5 9 3 8
# Surfaces of user 3: 2 6 4 7 0 1 5 9 3 8
# Surfaces of user 4: 2 6 4 7 0 1 5 9 3 8
# Surfaces of user 5: 2 6 4 7 0 1 5 3

# %% [markdown]
# Each user appears to have the same amount of surfaces, except for the last one\
# Select a few surfaces and get 100 records per each user and surface pair

# %%
def get_data_sample(slice_start: int, slice_end: int, surfaces: list):
    datasets = []
    for user_id in data_5.UserId.unique():
        for surface in surfaces:
            tmp = data_5[(data_5.UserId == user_id) & (data_5.Surface == surface)].iloc[slice_start:slice_end]
            tmp.insert(0, "id", list(range(surface * 100, surface * 100 + len(tmp))))
            datasets.append(tmp)

    df = pd.concat(datasets).reset_index(drop=True)
    # Sort values by id so that measurements from different users per each surface type are grouped together
    df.sort_values(by=["id"], inplace=True)

    # Add time column
    df.insert(0, "Time", list(range(1, len(df) + 1)))

    return df


surfaces = [1, 3, 5]
data_ts = get_data_sample(0, 100, surfaces)
data_ts
# Out:
#       Time   id  UserId  Surface      Acc_X     Acc_Y     Acc_Z  FreeAcc_X  \
# 0        1  100       1        1   9.655841 -0.802532 -2.329289   0.000000
# 300      2  100       2        1   9.456831 -0.693162 -0.868848  -0.000000
# 900      3  100       4        1   9.660328  0.825617 -1.808154  -0.043403
# 600      4  100       3        1   9.562259  0.458874 -2.338050  -0.000000
# 1200     5  100       5        1   9.001673  3.554755 -1.284438  -0.000000
# ...    ...  ...     ...      ...        ...       ...       ...        ...
# 1199  1496  599       4        5  10.639774  1.445141 -1.199068  -2.039918
# 599   1497  599       2        5   5.464766 -4.541182  8.435724  -4.742301
# 299   1498  599       1        5   4.969698  0.495670  3.027671   0.286370
# 899   1499  599       3        5   5.809286 -3.256449  3.884960  -2.585187
# 1499  1500  599       5        5   7.924886  4.932486 -0.422820  -1.042079
#
#       FreeAcc_Y  FreeAcc_Z  ...  VelInc_X  VelInc_Y  VelInc_Z  OriInc_q0  \
# 0      0.000000   0.152498  ...  0.096563 -0.008009 -0.023281   1.000000
# 300   -0.000000  -0.290765  ...  0.094564 -0.006954 -0.008722   1.000000
# 900   -0.090206   0.049512  ...  0.096605  0.008266 -0.018066   1.000000
# 600    0.000000   0.041948  ...  0.095625  0.004577 -0.023374   1.000000
# 1200   0.000000  -0.049687  ...  0.090007  0.035580 -0.012824   1.000000
# ...         ...        ...  ...       ...       ...       ...        ...
# 1199   2.974678   0.371661  ...  0.106408  0.014484 -0.011859   0.999991
# 599    0.565656   0.129030  ...  0.054433 -0.045629  0.084379   0.999991
# 299    0.591673  -4.009424  ...  0.049865  0.005071  0.029980   0.999974
# 899   -0.797670  -2.592934  ...  0.058415 -0.032427  0.038478   0.999977
# 1499   0.736592  -0.556156  ...  0.079251  0.049339 -0.004018   0.999997
#
#       OriInc_q1  OriInc_q2  OriInc_q3        Roll      Pitch         Yaw
# 0     -0.000458  -0.000087   0.000278 -161.015603 -75.696432  106.508134
# 300    0.000140   0.000343  -0.000248 -141.435076 -83.272463   85.065291
# 900   -0.000129  -0.000177   0.000128  152.699818 -78.243198  167.945963
# 600    0.000070  -0.000064  -0.000145  168.921902 -76.013552  131.784646
# 1200  -0.000702  -0.000500   0.000456  109.821241 -67.208230 -159.711687
# ...         ...        ...        ...         ...        ...         ...
# 1199   0.004222  -0.000659  -0.000168 -178.922481 -65.709882  148.398690
# 599    0.003074  -0.002960   0.000780   -7.093975 -49.988155  -52.934872
# 299   -0.004649   0.005492  -0.000505   -2.219655 -61.094297  -49.491748
# 899    0.000115   0.006314   0.002428   -9.049496 -58.352218  -57.773940
# 1499   0.002312  -0.001218   0.000059  108.974535 -55.808609 -147.198539
#
# [1500 rows x 26 columns]

# %%
# Map each id to a corresponding surface type
# NOTE: id is a 3 digit number and the hundreds digit is a surface code
classes = pd.Series(data_ts.id.unique() // 100, data_ts.id.unique())

# %%
features = extract_features(
    data_ts.drop(["UserId", "Surface"], axis=1),
    column_id="id",
    column_sort="Time",
    impute_function=impute
)

features
# Out:
# Feature Extraction: 100%|██████████| 30/30 [00:56<00:00,  1.87s/it]
#      Acc_X__variance_larger_than_standard_deviation  Acc_X__has_duplicate_max  \
# 100                                             0.0                       0.0
# 101                                             0.0                       0.0
# 102                                             0.0                       0.0
# 103                                             0.0                       0.0
# 104                                             0.0                       0.0
# ..                                              ...                       ...
# 595                                             1.0                       0.0
# 596                                             1.0                       0.0
# 597                                             1.0                       0.0
# 598                                             1.0                       0.0
# 599                                             1.0                       0.0
#
#      Acc_X__has_duplicate_min  Acc_X__has_duplicate  Acc_X__sum_values  \
# 100                       0.0                   0.0          47.336932
# 101                       0.0                   0.0          47.540364
# 102                       0.0                   0.0          47.612158
# 103                       0.0                   0.0          47.821013
# 104                       0.0                   0.0          47.345462
# ..                        ...                   ...                ...
# 595                       0.0                   0.0          34.370459
# 596                       0.0                   0.0          34.904235
# 597                       0.0                   0.0          35.274402
# 598                       0.0                   0.0          35.222331
# 599                       0.0                   0.0          34.808410
#
#      Acc_X__abs_energy  Acc_X__mean_abs_change  Acc_X__mean_change  \
# 100         448.455769                0.265291           -0.163542
# 101         452.385290                0.344005            0.018880
# 102         453.812420                0.348937           -0.077748
# 103         457.915780                0.374132           -0.131939
# 104         448.598057                0.154907            0.154907
# ..                 ...                     ...                 ...
# 595         273.318774                3.879417           -0.281672
# 596         273.849359                2.622464           -1.883641
# 597         273.114884                2.199727            1.093637
# 598         269.955110                3.702765            0.167779
# 599         264.317978                2.156316           -0.678722
#
#      Acc_X__mean_second_derivative_central  Acc_X__median  ...  \
# 100                              -0.060263       9.562259  ...
# 101                               0.093837       9.638948  ...
# 102                               0.115482       9.626419  ...
# 103                              -0.138688       9.658233  ...
# 104                              -0.087512       9.584026  ...
# ..                                     ...            ...  ...
# 595                               0.423266       7.039631  ...
# 596                               0.072662       6.681120  ...
# 597                               0.779130       6.294757  ...
# 598                              -1.367381       6.042614  ...
# 599                               1.215101       5.809286  ...
#
#      Yaw__permutation_entropy__dimension_6__tau_1  \
# 100                                           0.0
# 101                                           0.0
# 102                                           0.0
# 103                                           0.0
# 104                                           0.0
# ..                                            ...
# 595                                           0.0
# 596                                           0.0
# 597                                           0.0
# 598                                           0.0
# 599                                           0.0
#
#      Yaw__permutation_entropy__dimension_7__tau_1  \
# 100                                           0.0
# 101                                           0.0
# 102                                           0.0
# 103                                           0.0
# 104                                           0.0
# ..                                            ...
# 595                                           0.0
# 596                                           0.0
# 597                                           0.0
# 598                                           0.0
# 599                                           0.0
#
#      Yaw__query_similarity_count__query_None__threshold_0.0  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__matrix_profile__feature_"min"__threshold_0.98  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__matrix_profile__feature_"max"__threshold_0.98  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__matrix_profile__feature_"mean"__threshold_0.98  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__matrix_profile__feature_"median"__threshold_0.98  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__matrix_profile__feature_"25"__threshold_0.98  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__matrix_profile__feature_"75"__threshold_0.98  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__mean_n_absolute_max__number_of_maxima_7
# 100                                           0.0
# 101                                           0.0
# 102                                           0.0
# 103                                           0.0
# 104                                           0.0
# ..                                            ...
# 595                                           0.0
# 596                                           0.0
# 597                                           0.0
# 598                                           0.0
# 599                                           0.0
#
# [300 rows x 17358 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, classes, test_size=.2)

# %%
relevant_features = set()

for label in classes.unique():
    targets_binary = y_train == label
    print(len(targets_binary))
    features_filtered = select_features(X_train, targets_binary)
    print("Number of relevant features for class {}: {}/{}".format(label, features_filtered.shape[1], features.shape[1]))
    relevant_features = relevant_features.union(set(features_filtered.columns))
# Out:
# 240
# Number of relevant features for class 1: 635/17358
# 240
# Number of relevant features for class 3: 647/17358
# 240
# Number of relevant features for class 5: 623/17358

# %% [markdown]
# ### Let's train a model

# %%
print("Amount of relevant features:", len(relevant_features))

X_train_filtered = X_train[list(relevant_features)]
X_test_filtered = X_test[list(relevant_features)]
# Out:
# Amount of relevant features: 1173

# %%
classifier_selected = DecisionTreeClassifier()
classifier_selected.fit(X_train_filtered, y_train)

print(classification_report(y_test, classifier_selected.predict(X_test_filtered)))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            3       1.00      0.94      0.97        16
#            5       0.96      1.00      0.98        22
#
#     accuracy                           0.98        60
#    macro avg       0.99      0.98      0.98        60
# weighted avg       0.98      0.98      0.98        60

# %%
classifier_full = DecisionTreeClassifier()
classifier_full.fit(X_train, y_train)
print(classification_report(y_test, classifier_full.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            3       1.00      1.00      1.00        16
#            5       1.00      1.00      1.00        22
#
#     accuracy                           1.00        60
#    macro avg       1.00      1.00      1.00        60
# weighted avg       1.00      1.00      1.00        60

# %% [markdown]
# #### Precision of 100% is absolutely unrealistic, there seems to be no variance between train and test data
# #### Let's check how our model performs with unseen data

# %%
surfaces = [1, 3, 5]
data_ts = get_data_sample(800, 900, surfaces)
data_ts
# Out:
#       Time   id  UserId  Surface      Acc_X     Acc_Y      Acc_Z  FreeAcc_X  \
# 0        1  100       1        1  -0.803406 -2.071275  -4.595924  -0.086164
# 300      2  100       2        1  15.591149 -5.502933  16.183249  -8.069631
# 900      3  100       4        1  17.531020 -1.686792  -2.906607  -2.125449
# 600      4  100       3        1  12.599671  2.543136   1.036400  -3.080940
# 1200     5  100       5        1   4.857637  4.854209  -0.980034   3.807336
# ...    ...  ...     ...      ...        ...       ...        ...        ...
# 1199  1496  599       4        5  15.744431  2.118684   2.694547  -7.423905
# 599   1497  599       2        5  32.464102  0.155519  11.478311   1.164892
# 299   1498  599       1        5   2.984693 -0.124149  -0.032814   0.807783
# 899   1499  599       3        5  -1.118383  0.798236  -8.602852   4.747116
# 1499  1500  599       5        5  13.829352  7.524277   8.679743 -11.380360
#
#       FreeAcc_Y  FreeAcc_Z  ...  VelInc_X  VelInc_Y  VelInc_Z  OriInc_q0  \
# 0     -4.248959 -12.640564  ... -0.007875 -0.020889 -0.045907   0.999988
# 300    4.284502  11.440798  ...  0.153215 -0.058827  0.163044   0.999687
# 900   -1.790845   7.818901  ...  0.174689 -0.018760 -0.031487   0.999803
# 600    5.858032   1.254564  ...  0.125944  0.025522  0.010776   0.999994
# 1200  -1.366017  -4.177562  ...  0.048840  0.048476 -0.008738   0.999852
# ...         ...        ...  ...       ...       ...       ...        ...
# 1199   6.599238   2.874682  ...  0.157621  0.020970  0.026065   0.999980
# 599    1.304030  24.575977  ...  0.325328  0.005015  0.112696   0.999905
# 299   -1.141641  -7.172849  ...  0.029848 -0.001257 -0.000039   0.999937
# 899   -5.946602 -14.054461  ... -0.011857  0.006676 -0.086046   0.999849
# 1499   8.183147   1.444397  ...  0.139089  0.074561  0.086110   0.999955
#
#       OriInc_q1  OriInc_q2  OriInc_q3        Roll      Pitch         Yaw
# 0     -0.003719  -0.003148   0.000716   -4.548070 -61.554669  -56.582956
# 300    0.019510  -0.015145  -0.004049   -4.317328 -65.302512  -53.251243
# 900   -0.009551   0.014830  -0.009142  164.437101 -77.320976  169.137469
# 600    0.001005  -0.003065   0.000802  171.895120 -64.121287  141.336521
# 1200   0.015398  -0.006465  -0.004222   48.271501 -59.427731 -110.335825
# ...         ...        ...        ...         ...        ...         ...
# 1199   0.002147   0.005872  -0.001020 -171.816081 -63.367240  148.353598
# 599   -0.009891   0.006301   0.007192   -9.522515 -70.621780  -46.588363
# 299   -0.006118  -0.009447  -0.000479   -8.619569 -63.015345  -49.375057
# 899   -0.015390   0.007947  -0.001538   -1.156497 -67.705410  -57.096309
# 1499   0.005167   0.007736  -0.001700  132.988779 -56.628692 -160.048967
#
# [1500 rows x 26 columns]

# %%
features = extract_features(
    data_ts.drop(["UserId", "Surface"], axis=1),
    column_id="id",
    column_sort="Time",
    impute_function=impute
)
features
# Out:
# Feature Extraction: 100%|██████████| 30/30 [01:06<00:00,  2.20s/it]
#      Acc_X__variance_larger_than_standard_deviation  Acc_X__has_duplicate_max  \
# 100                                             1.0                       0.0
# 101                                             1.0                       0.0
# 102                                             1.0                       0.0
# 103                                             1.0                       0.0
# 104                                             1.0                       0.0
# ..                                              ...                       ...
# 595                                             1.0                       0.0
# 596                                             1.0                       0.0
# 597                                             1.0                       0.0
# 598                                             1.0                       0.0
# 599                                             1.0                       0.0
#
#      Acc_X__has_duplicate_min  Acc_X__has_duplicate  Acc_X__sum_values  \
# 100                       0.0                   0.0          49.776071
# 101                       0.0                   0.0          64.848807
# 102                       0.0                   0.0          87.340741
# 103                       0.0                   0.0          97.610107
# 104                       0.0                   0.0          77.164842
# ..                        ...                   ...                ...
# 595                       0.0                   0.0          30.922496
# 596                       0.0                   0.0          38.203487
# 597                       0.0                   0.0          49.444702
# 598                       0.0                   0.0          63.484013
# 599                       0.0                   0.0          63.904195
#
#      Acc_X__abs_energy  Acc_X__mean_abs_change  Acc_X__mean_change  \
# 100         733.414397                7.751952            1.415261
# 101        1113.722007               13.385055            1.415403
# 102        1959.501231               10.949699            2.938197
# 103        2428.813743               17.033417            4.635230
# 104        1324.090569                9.388101           -0.507681
# ..                 ...                     ...                 ...
# 595         323.821926                5.382637           -3.105492
# 596         487.782995               12.658515            0.403449
# 597         894.629867               15.458310            3.255663
# 598        1567.842603               15.868965           -8.135335
# 599        1503.215176               16.312473           -0.478770
#
#      Acc_X__mean_second_derivative_central  Acc_X__median  ...  \
# 100                              -4.022765      12.599671  ...
# 101                               3.570169      13.353338  ...
# 102                              -4.370324      19.453159  ...
# 103                               3.836674      18.942164  ...
# 104                               2.830072      17.454538  ...
# ..                                     ...            ...  ...
# 595                              -1.113546       6.024110  ...
# 596                               4.263833      12.003591  ...
# 597                              -4.106964      12.726877  ...
# 598                               0.939882      14.505172  ...
# 599                              -0.295323      13.829352  ...
#
#      Yaw__permutation_entropy__dimension_6__tau_1  \
# 100                                           0.0
# 101                                           0.0
# 102                                           0.0
# 103                                           0.0
# 104                                           0.0
# ..                                            ...
# 595                                           0.0
# 596                                           0.0
# 597                                           0.0
# 598                                           0.0
# 599                                           0.0
#
#      Yaw__permutation_entropy__dimension_7__tau_1  \
# 100                                           0.0
# 101                                           0.0
# 102                                           0.0
# 103                                           0.0
# 104                                           0.0
# ..                                            ...
# 595                                           0.0
# 596                                           0.0
# 597                                           0.0
# 598                                           0.0
# 599                                           0.0
#
#      Yaw__query_similarity_count__query_None__threshold_0.0  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__matrix_profile__feature_"min"__threshold_0.98  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__matrix_profile__feature_"max"__threshold_0.98  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__matrix_profile__feature_"mean"__threshold_0.98  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__matrix_profile__feature_"median"__threshold_0.98  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__matrix_profile__feature_"25"__threshold_0.98  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__matrix_profile__feature_"75"__threshold_0.98  \
# 100                                                0.0
# 101                                                0.0
# 102                                                0.0
# 103                                                0.0
# 104                                                0.0
# ..                                                 ...
# 595                                                0.0
# 596                                                0.0
# 597                                                0.0
# 598                                                0.0
# 599                                                0.0
#
#      Yaw__mean_n_absolute_max__number_of_maxima_7
# 100                                           0.0
# 101                                           0.0
# 102                                           0.0
# 103                                           0.0
# 104                                           0.0
# ..                                            ...
# 595                                           0.0
# 596                                           0.0
# 597                                           0.0
# 598                                           0.0
# 599                                           0.0
#
# [300 rows x 17358 columns]

# %%
# Full feature set
print(classification_report(classes, classifier_full.predict(features)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.39      0.79      0.52       100
#            3       0.00      0.00      0.00       100
#            5       0.61      0.58      0.59       100
#
#     accuracy                           0.46       300
#    macro avg       0.33      0.46      0.37       300
# weighted avg       0.33      0.46      0.37       300
# /Users/aidarmamytov/University/Dissertation/.venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/aidarmamytov/University/Dissertation/.venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/aidarmamytov/University/Dissertation/.venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Filtered feature set
X_test_filtered = features[list(relevant_features)]
print(classification_report(classes, classifier_selected.predict(X_test_filtered)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.42      0.95      0.58       100
#            3       1.00      0.06      0.11       100
#            5       0.92      0.61      0.73       100
#
#     accuracy                           0.54       300
#    macro avg       0.78      0.54      0.48       300
# weighted avg       0.78      0.54      0.48       300

# %%
rdf_full = RandomForestClassifier()
rdf_full.fit(X_train, y_train)
print(classification_report(y_test, rdf_full.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            3       1.00      1.00      1.00        16
#            5       1.00      1.00      1.00        22
#
#     accuracy                           1.00        60
#    macro avg       1.00      1.00      1.00        60
# weighted avg       1.00      1.00      1.00        60

# %%
# classifier_selected = DecisionTreeClassifier()
# classifier_selected.fit(X_train_filtered, y_train)

# print(classification_report(y_test, classifier_selected.predict(X_test_filtered)))
rdf_selected = RandomForestClassifier()
rdf_selected.fit(X_train_filtered, y_train)
print(classification_report(classes, rdf_selected.predict(X_test_filtered)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      1.00      0.67       100
#            3       0.00      0.00      0.00       100
#            5       1.00      1.00      1.00       100
#
#     accuracy                           0.67       300
#    macro avg       0.50      0.67      0.56       300
# weighted avg       0.50      0.67      0.56       300
# /Users/aidarmamytov/University/Dissertation/.venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/aidarmamytov/University/Dissertation/.venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/aidarmamytov/University/Dissertation/.venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Result: Decision Tree classifier performance on unseen data is quite poor
